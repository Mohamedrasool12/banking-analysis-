# %%
import pandas as pd 
data=pd.read_csv('/Users/dam115/Downloads/data9.csv')
data2=data[ data["TRANSACTION_DESCRIPTION"].isnull() ==False]
data2= data2[data2['AMT']>0]
#data2['TRANSACTION_DESCRIPTION'].value_counts()
data2
# Out:
#        DATE_LAST_UPDATED GENDER  INCOME_GROUP_CODE  NUMBER_OF_ACCOUNTS  \
# 182               22-Aug   male                 11                   7
# 301               22-Aug   male                 11                  10
# 306               22-Aug   male                 11                  10
# 308               22-Aug   male                 11                  10
# 313               22-Jun   male                 11                   7
# ...                  ...    ...                ...                 ...
# 847271            22-Aug   male                 20                   6
# 847284            22-Aug   male                 20                   6
# 847289            22-Aug   male                 20                   6
# 847399            22-Sep   male                 21                   4
# 847403            22-Aug   male                 21                  14
#
#         OCCUPATIONAL_STATUS_CODE    AGE  N_CUSTOMER_ID  income_group_code  \
# ...

# %%
data2 =data[data["AMT"] >0]
data2
# Out:
#        DATE_LAST_UPDATED GENDER  INCOME_GROUP_CODE  NUMBER_OF_ACCOUNTS  \
# 12                22-Sep   male                 11                   6
# 13                22-Sep   male                 11                   6
# 17                22-Sep   male                 11                   6
# 24                22-Sep   male                 11                   6
# 25                22-Sep   male                 11                   6
# ...                  ...    ...                ...                 ...
# 847539            22-Aug   male                  0                   5
# 847540            22-Aug   male                  0                   5
# 847541            22-Aug   male                  0                   5
# 847542            22-Aug   male                  0                   5
# 847543            22-Aug   male                  0                   5
#
#         OCCUPATIONAL_STATUS_CODE    AGE  N_CUSTOMER_ID  income_group_code  \
# ...

# %%
dat = data[data['CHANNEL'] == "atm"]
dats = dat[dat["AMT"] < 0]
top = dats["TRANSACTION_DESCRIPTION"].value_counts().head(60)
top
# Out:
# TRANSACTION_DESCRIPTION
# ATM WITHDRAWAL        38894
# AIRTIME DEBIT         37079
# LOTTO PURCHASE        11453
# PREPAID DEBIT          5403
# TRI ATM WITHDRAWAL     1559
# ATM PAYMENT TO          294
# CASHSEND ATM            254
# ATM TRANSFER            250
# SCAN TRANSFER TO         13
# SSD OTHER CHIP WDL        3
# AIRTIME DBT ATMS          1
# Name: count, dtype: int64

# %%
filtered_df = data[data["TRANSACTION_DESCRIPTION"] == "CAN CASHSEND IB"]
filtered_df["AMT"].max()
#filtered_df.info()
# Out:
# 3000.0

# %%
data2 = data[data['TRANSACTION_DESCRIPTION'].isnull() == True]

data2 = data2[data2['CHANNEL'] == "system"]
data2A = data2[(data2['AMT'] <= -0.01) & (data2['AMT'] <= -460.99)]

data2A.fillna("MANAGEMENT FEE", inplace = True)
# Out:
# /var/folders/30/7msgh4hj1hz__h5k3cmyhyqh0000gn/T/ipykernel_37068/1853322225.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data2A.fillna("MANAGEMENT FEE", inplace = True)

# %%
data2 = data[data['TRANSACTION_DESCRIPTION'].isnull() == True]

data2 = data2[data2['CHANNEL'] == "system"]
data2B = data2[(data2['AMT'] <= -461.00) & (data2['AMT'] <= -12284.99)]

data2B.fillna("ACB DEBIT:EXTERNAL", inplace = True)
# Out:
# /var/folders/30/7msgh4hj1hz__h5k3cmyhyqh0000gn/T/ipykernel_37068/2944254716.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data2B.fillna("ACB DEBIT:EXTERNAL", inplace = True)

# %% [markdown]
# ATM

# %%
data2 = data[data['TRANSACTION_DESCRIPTION'].isnull() == True]

data2 = data2[data2['CHANNEL'] == "atm"]
data2C = data2[(data2['AMT'] <= -0.01) & (data2['AMT'] >= -699.99)]

data2C.fillna("AIRTIME DEBIT", inplace = True) 
data2C
# Out:
# /var/folders/30/7msgh4hj1hz__h5k3cmyhyqh0000gn/T/ipykernel_37068/3128794553.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data2C.fillna("AIRTIME DEBIT", inplace = True)
#        DATE_LAST_UPDATED  GENDER  INCOME_GROUP_CODE  NUMBER_OF_ACCOUNTS  \
# 1                 22-Sep    male                 11                   6
# 2                 22-Sep    male                 11                   6
# 3                 22-Sep    male                 11                   6
# 6                 22-Sep    male                 11                   6
# 7                 22-Sep    male                 11                   6
# ...                  ...     ...                ...                 ...
# 847508            22-Apr  female                  0                   4
# ...

# %%
data2 = data[data['TRANSACTION_DESCRIPTION'].isnull() == True]

data2 = data2[data2['CHANNEL'] == "atm"]
data2D = data2[(data2['AMT'] <= -700.00) & (data2['AMT'] >= -750.99)]

data2D.fillna("LOTTO PURCHASE", inplace = True) 
data2D
# Out:
# /var/folders/30/7msgh4hj1hz__h5k3cmyhyqh0000gn/T/ipykernel_37068/1728036463.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data2D.fillna("LOTTO PURCHASE", inplace = True)
#        DATE_LAST_UPDATED  GENDER  INCOME_GROUP_CODE  NUMBER_OF_ACCOUNTS  \
# 22                22-Sep    male                 11                   6
# 28                22-Sep    male                 11                   6
# 127               22-Sep    male                 11                   6
# 145               22-Sep    male                 11                   6
# 282               22-Aug    male                 11                   7
# ...                  ...     ...                ...                 ...
# 837260            22-Jul    male                  1                   4
# ...

# %%
data2 = data[data['TRANSACTION_DESCRIPTION'].isnull() == True]

data2 = data2[data2['CHANNEL'] == "atm"]
data2E = data2[(data2['AMT'] <= -751.00) & (data2['AMT'] >= -1000.99)]
data2E.fillna("PREPAID DEBIT ", inplace = True) 
data2E
# Out:
# /var/folders/30/7msgh4hj1hz__h5k3cmyhyqh0000gn/T/ipykernel_37068/3877038483.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data2E.fillna("PREPAID DEBIT ", inplace = True)
#        DATE_LAST_UPDATED  GENDER  INCOME_GROUP_CODE  NUMBER_OF_ACCOUNTS  \
# 0                 22-Sep    male                 11                   6
# 23                22-Sep    male                 11                   6
# 27                22-Sep    male                 11                   6
# 66                22-Sep    male                 11                   6
# 67                22-Sep    male                 11                   6
# ...                  ...     ...                ...                 ...
# 842591            22-Aug    male                  1                   8
# ...

# %%
data2 = data[data['TRANSACTION_DESCRIPTION'].isnull() == True]

data2 = data2[data2['CHANNEL'] == "atm"]
data2F = data2[(data2['AMT'] <= -1001.00) & (data2['AMT'] >= -5000.00)]
data2F.fillna("ATM WITHDRAWAL", inplace = True)
data2F
# Out:
# /var/folders/30/7msgh4hj1hz__h5k3cmyhyqh0000gn/T/ipykernel_37068/1960473805.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data2F.fillna("ATM WITHDRAWAL", inplace = True)
#        DATE_LAST_UPDATED  GENDER  INCOME_GROUP_CODE  NUMBER_OF_ACCOUNTS  \
# 29                22-Sep    male                 11                   6
# 33                22-Sep    male                 11                   6
# 34                22-Sep    male                 11                   6
# 79                22-Sep    male                 11                   6
# 84                22-Sep    male                 11                   6
# ...                  ...     ...                ...                 ...
# 845315            22-Jul  female                  1                   5
# ...

# %% [markdown]
# TELLER CREDIT

# %%
data2 = data[data['TRANSACTION_DESCRIPTION'].isnull() == True]

data2 = data2[data2['CHANNEL'] == "teller"]
data2G = data2[(data2['AMT'] >= 0) & (data2['AMT'] <= 46998.99)]
data2G.fillna("IMMEDIATE TRF CR", inplace = True)
data2G
# Out:
# /var/folders/30/7msgh4hj1hz__h5k3cmyhyqh0000gn/T/ipykernel_37068/1681538922.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data2G.fillna("IMMEDIATE TRF CR", inplace = True)
#        DATE_LAST_UPDATED  GENDER  INCOME_GROUP_CODE  NUMBER_OF_ACCOUNTS  \
# 13                22-Sep    male                 11                   6
# 59                22-Sep    male                 11                   6
# 88                22-Sep    male                 11                   6
# 227               22-Aug    male                 11                   7
# 502               22-Sep    male                 11                  13
# ...                  ...     ...                ...                 ...
# 847444            22-Apr  female                  0                   4
# ...

# %%
data2 = data[data['TRANSACTION_DESCRIPTION'].isnull() == True]

data2 = data2[data2['CHANNEL'] == "teller"]
data2H = data2[(data2['AMT'] >= 46999.00) & (data2['AMT'] <= 49162.99)]
data2H.fillna("OPENED-FROM SAV", inplace = True)
data2H
# Out:
# /var/folders/30/7msgh4hj1hz__h5k3cmyhyqh0000gn/T/ipykernel_37068/2285041475.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data2H.fillna("OPENED-FROM SAV", inplace = True)
#        DATE_LAST_UPDATED  GENDER  INCOME_GROUP_CODE  NUMBER_OF_ACCOUNTS  \
# 174488            22-Sep  female                 12                   9
# 204541            22-Jun  female                 12                  14
# 642448            22-Sep  female                 16                  11
# 789471            22-Sep  female                  4                  10
# 805561            22-Jul    male                  3                  11
#
#         OCCUPATIONAL_STATUS_CODE    AGE  N_CUSTOMER_ID  income_group_code  \
# 174488                         1  26-35            752                 12
# ...

# %%
data2 = data[data['TRANSACTION_DESCRIPTION'].isnull() == True]

data2 = data2[data2['CHANNEL'] == "internet"]
data2I = data2[(data2['AMT'] >= 0.01) & (data2['AMT'] <= 3000.99)]
data2I.fillna("CAN CASHSEND IB", inplace = True)
# Out:
# /var/folders/30/7msgh4hj1hz__h5k3cmyhyqh0000gn/T/ipykernel_37068/3114608357.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data2I.fillna("CAN CASHSEND IB", inplace = True)
#        DATE_LAST_UPDATED  GENDER  INCOME_GROUP_CODE  NUMBER_OF_ACCOUNTS  \
# 12                22-Sep    male                 11                   6
# 17                22-Sep    male                 11                   6
# 24                22-Sep    male                 11                   6
# 25                22-Sep    male                 11                   6
# 31                22-Sep    male                 11                   6
# ...                  ...     ...                ...                 ...
# 847316            22-Jul    male                 21                  10
# ...

# %%
data2 = data[data['TRANSACTION_DESCRIPTION'].isnull() == True]

data2 = data2[data2['CHANNEL'] == "internet"]
data2J = data2[(data2['AMT'] >= 3001.00) & (data2['AMT'] <= 40000.99)]
data2J.fillna("DIGITAL TRANSF CR", inplace = True)
data2J
# Out:
# /var/folders/30/7msgh4hj1hz__h5k3cmyhyqh0000gn/T/ipykernel_37068/3153315977.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data2J.fillna("DIGITAL TRANSF CR", inplace = True)
#        DATE_LAST_UPDATED  GENDER  INCOME_GROUP_CODE  NUMBER_OF_ACCOUNTS  \
# 273               22-Aug    male                 11                   7
# 1542              22-Aug    male                 11                  11
# 1602              22-Jun    male                 11                   6
# 1662              22-Jun    male                 11                   6
# 1731              22-Sep    male                 11                  12
# ...                  ...     ...                ...                 ...
# 846870            22-Sep    male                 20                  10
# ...

# %%
data2 = data[data['TRANSACTION_DESCRIPTION'].isnull() == True]

data2 = data2[data2['CHANNEL'] == "internet"]
data2K = data2[(data2['AMT'] >= 40001.00) & (data2['AMT'] <= 43000.99)]
data2K.fillna("IBANK TRANSFER", inplace = True)
data2K
# Out:
# /var/folders/30/7msgh4hj1hz__h5k3cmyhyqh0000gn/T/ipykernel_37068/1312296997.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data2K.fillna("IBANK TRANSFER", inplace = True)
#        DATE_LAST_UPDATED  GENDER  INCOME_GROUP_CODE  NUMBER_OF_ACCOUNTS  \
# 230549            22-May    male                 12                   4
# 657540            22-Sep  female                 16                  17
# 658250            22-Sep    male                 16                   5
#
#         OCCUPATIONAL_STATUS_CODE    AGE  N_CUSTOMER_ID  income_group_code  \
# 230549                         1  46-55           4804                 12
# 657540                         1  36-45           2378                 16
# 658250                         1  56-65           2426                 16
#
# ...

# %%
data2 = data[data['TRANSACTION_DESCRIPTION'].isnull() == True]

data2 = data2[data2['CHANNEL'] == "internet"]
data2K = data2[(data2['AMT'] >= 43001.00) & (data2['AMT'] <= 50000.99)]
data2K.fillna("IBANK PAYMENT FROM", inplace = True)
data2K
# Out:
# /var/folders/30/7msgh4hj1hz__h5k3cmyhyqh0000gn/T/ipykernel_37068/2126076036.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data2K.fillna("IBANK PAYMENT FROM", inplace = True)
#        DATE_LAST_UPDATED  GENDER  INCOME_GROUP_CODE  NUMBER_OF_ACCOUNTS  \
# 39068             22-Sep    male                 14                  14
# 71704             22-Jul    male                 14                   9
# 189819            22-Jul  female                 12                   6
# 330783            22-Sep    male                 15                   7
# 369320            22-Sep  female                  6                   8
# 586870            22-Sep  female                 17                  10
# 625638            22-Sep    male                 16                   8
# ...
